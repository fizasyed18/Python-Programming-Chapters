# %% [markdown]
# ### **Operators**
#
# Operators are used to perform operations on variables and values.
# - Operators: Special symbols like -, + , * , /, etc.
# - Operands: Value on which the operator is applied.
#
# | **Types** | **Operators** |
# |---|---|
# | **Arithmetic Operators** | +, -, *, /, % |
# | **Comparison Operators** | <, <=, >, >=, ==, != |
# | **Logical Operators** | AND, OR, NOT |
# | **Bitwise Operators** | &, ^, ~, <<, >>|
# | **Assignment Operators** | =, +=, -=, *=, %= |
# | **Ternary Operators** | x if condition else y |
# | **Identity Operators** | is, is not |

# %% [markdown]
# **1. Arithmetic Operators**
#
# Arithmetic operators are used to perform basic mathematical operations like addition, subtraction, multiplication and division.

# %%
x = 20
y = 3

print(x + y)    # Addition
print(x - y)    # Subtraction
print(x * y)    # Multiplication
print(x / y)    # Division - Returns a float
print(x // y)   # Floor Division - Returns an integer
print(x % y)    # Modulus
print(x ** y)   # Exponentiation
# Out:
# 23
# 17
# 60
# 6.666666666666667
# 6
# 2
# 8000

# %% [markdown]
# **2. Comparison Operators**
#
# Comparison operators are used to compare two values. It either returns True or False according to the condition.

# %%
x = 10
y = 7

print(x > y)
print(x < y)
print(x == y)
print(x != y)
print(x >= y)
print(x <= y)
# Out:
# True
# False
# False
# True
# True
# False

# %% [markdown]
# **3. Logical Operators**
#
# Logical operators are used to combine conditional statements.

# %%
# Test if a number is greater than 0 and less than 10

x = 5
print(x > 0 and x < 10)

print("--------------")

# Test if a number is less than 5 or greater than 10

x = 5
print(x < 5 or x > 10)

print("--------------")

# Reverse the result with not

x = 5
print(not(x > 3 and x < 10))
# Out:
# True
# --------------
# False
# --------------
# False

# %% [markdown]
# **4. Bitwise Operators**
#
# Bitwise operators act on bits and perform bit-by-bit operations. These are used to operate on binary numbers.

# %%
x = 10
y = 3

print(x & y)    # Bitwise AND
print(x | y)    # Bitwise OR
print(~x)       # Bitwise NOT
print(x ^ y)    # Bitwise XOR
print(x >> 2)   # Bitwsie Zero fill right shift
print(x << 2)   # Bitwsie Zero fill left shift
# Out:
# 2
# 11
# -11
# 9
# 2
# 40

# %% [markdown]
# **5. Assignment Operators**
#
# Assignment operators are used to assign values to the variables. This operator is used to assign the value of the right side of the expression to the left side operand.

# %%
# Addition Assignment Operator

a = 7
b = 10

a += b
print(a)
# Out:
# 17

# %%
# Subtraction Assignment Operator

a = 7
b = 10

a -= b
print(a)
# Out:
# -3

# %%
# Multiplication Assignment Operator

a = 7
b = 10

a *= b
print(a)
# Out:
# 70

# %%
# Division Assignment Operator

a = 7
b = 10

a /= b      
print(a)
# Out:
# 0.7

# %%
# Modulus Assignment Operator

a = 7
b = 10

a %= b
print(a)
# Out:
# 7

# %%
# Floor Division Assignment Operator

a = 7
b = 10

a //= b
print(a)
# Out:
# 0

# %%
# Exponentiation Assignment Operator

a = 7
b = 10

a **= b
print(a)
# Out:
# 282475249

# %%
# Bitwise AND Assignment Operator

a = 7
b = 10

a &= b
print(a)
# Out:
# 2

# %%
# Bitwise OR Assignment Operator

a = 7
b = 10

a |= b
print(a)
# Out:
# 15

# %%
# Bitwise XOR Assignment Operator 

a = 7
b = 10

a ^= b
print(a)
# Out:
# 13

# %%
# Bitwise Right Shift Assignment Operator

a = 7
b = 10

a >>= b
print(a)
# Out:
# 0

# %%
# Bitwise Left Shift Assignment Operator

a = 7
b = 10

a <<= b
print(a)
# Out:
# 7168

# %% [markdown]
# **6. Ternary Operators**
#
# The ternary operator allows you to assign one value if a condition is true, and another if it is false

# %%
# Assign the value "WEEKEND!" if the number is higher than 5, otherwise "Workday"

num = 10
x = "WEEKEND!" if num > 5 else "Workday"

print(x)
# Out:
# WEEKEND!

# %% [markdown]
# **Ways to Use Ternary Operator**

# %% [markdown]
# - **Nested If-Else**

# %%
num = -5
result = "Positive" if num > 0 else "Negative" if num < 0 else "Zero"

print(result)

# Explanation:

# First, it checks if num > 0. If True, it returns "Positive".
# If False, it checks if num < 0. If True, it returns "Negative".
# If both conditions fail, it defaults to "Zero".
# Out:
# Negative

# %% [markdown]
# - **Tuple**

# %%
num = 7
result = ("Odd", "Even")[num % 2 == 0]

print(result)

# Explanation: 

# The condition num % 2 == 0 evaluates to False (index 0), so it selects "Odd".
# Out:
# Odd

# %% [markdown]
# - **Dictionary**

# %%
x = 10
y = 20

result = {True : x, False: y}[x > y]
print(result)

# Explanation: 

# This uses a dictionary where the key is True or False based on the condition a > b. The corresponding value (a or b) is then selected.
# Out:
# 20

# %% [markdown]
# - **Using Ternary Operator Inside Lambda Function**

# %%
x = 10
y = 20

result = (lambda x, y: x if x > y else y)(x, y)
print(result)

# Explanation: 

# This defines an anonymous function (lambda) that takes two arguments and returns the larger one using the ternary operator. It is then called with a and b.
# Out:
# 20

# %% [markdown]
# - **Print Function**

# %%
x = 10
y = 20

print("x is greater" if x > y else "b is greater")

# Explanation: 

# This checks if a is greater than b. If true, it prints "a is greater"; otherwise, it prints "b is greater".
# Out:
# b is greater

# %% [markdown]
# **7. Identity Operators**
#
# The identity operators are used to check if two values are located on the same part of the memory.

# %%
# The is operator returns True if both variables point to the same object

x = ["apple", "orange"]
y = ["apple", "orange"]
z = x

print(x is z)       # is - Checks if both variables point to the same object in memory
print(x is y)
print(x == y)       # == - Checks if the values of both variables are equal

print("--------------")

# The is not operator returns True if both variables do not point to the same object

x = ["apple", "orange"]
y = ["apple", "orange"]

print(x is not y)
# Out:
# True
# False
# True
# --------------
# True
